# %% [markdown]
# #Import Libraries

# %%
import sklearn
from sklearn.datasets import fetch_openml
import random

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score       #misura l'accuratezza del programma usando i dati non di training

# %% [markdown]
# #Load Data

# %%
mnist = fetch_openml('mnist_784')
mnist

# %%
import pandas as pd


x, y = mnist['data'], mnist['target']
x = x.to_numpy()
random_digit = x[random.randint(1,10000)]
some_random_digit = random_digit.reshape(28,28)
plt.imshow(some_random_digit, cmap = matplotlib.cm.binary)

# %%
x_train, x_test = x[:60000], x[60000:70000]
y_train, y_test = y[:60000], y[60000:70000]

shuffle_index = np.random.permutation(60000)
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]

# %% [markdown]
# #Define Model

# %%
model = LogisticRegression(tol=0.1, max_iter=2000) #tol è la tolleranza, criterio per fermarsi
                                                    #max-iter: massimo numero di iterazioni entro le quali soluzione deve convergere

# %%
y_train.shape

# %% [markdown]
# #Train Model

# %%
model.fit(x_train, y_train)       #questo passo richiede un quarto d'ora

# %% [markdown]
# #Find the Output

# %%
test_num = int(input('Select and number between 1 and 10,000 to select the image:'))
test_image_data = x_test[test_num]
test_image = test_image_data.reshape(28,28)

prediction = model.predict([test_image_data])

plt.imshow(test_image,cmap = matplotlib.cm.binary)
plt.title(f'Selected Image Number: {test_num}')
plt.xlabel(f'The image has been classified as: {prediction[0]}')
