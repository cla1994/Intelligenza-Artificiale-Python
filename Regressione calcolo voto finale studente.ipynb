# %% [markdown]
# ## Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os
work_dir = '/content/drive/My Drive/SKILLIT Courses/AI Level 2/Regression'
os.chdir(work_dir) # mi sposto in cartella dove si trova il file .csv

# %% [markdown]
# ## Import Modules

# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv("student_marks.csv", sep=",")
print(data.head())

# %% [markdown]
# ## Separate Data

# %%
predict = "final"

x = np.array(data.drop([predict], axis = 1)) # aggiunto axis = 1
y = np.array(data[predict])

x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(x, y, test_size = 0.1)

# %% [markdown]
# ## Define Model

# %%
linear = linear_model.LinearRegression()

linear.fit(x_train, y_train)
acc = linear.score(x_test, y_test)

print(acc)

# %% [markdown]
# ## Constants of "Best-Fit" Equation

# %%
print('Coefficient: \n', linear.coef_) # y = mx + c da x1 x2 x3 x4 x5
print('Intercept: \n', linear.intercept_)

# %% [markdown]
# ## Predictions for Specific Students

# %%
predictions = linear.predict(x_test)

for x in range(len(predictions)):
  print(f'Predicted value:{predictions[x]:0.1f}\t inputs: {x_test[x]}\t Actual Output:{y_test[x]}')

# %%
print("**********************FINAL SCORE PREDICTOR***********************************")
studytime = input('How many hours do you study per day: ')
absences= input('How many times were you absent during this semester: ')
failures = input('How many times have failed in a class before: ')
assignments = input('How many marks did you score in your assignments (out of 20): ') # Da 1 a 20 qual era il voto dato ai tuoi compiti a casa / relazioni
midterm = input('What was your score in mid-term (out of 20): ') # Da 1 a 20 qual era il tuo voto all'esame di metà anno

data = [[int(studytime), int(absences), int(failures), int(assignments), int(midterm)]]
print(data)
print('*******************************************************************************')
prediction = linear.predict(data)
print(f'The model expects that you will score {prediction[0]:0.2f} in your finals') # Voto all'esame finale
print('*******************************************************************************')
